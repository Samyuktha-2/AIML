# %%
pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)

# %%
from transformers import pipeline
from groq import Groq
from google.colab import userdata

# Step 1: Load image classification model
classifier = pipeline("image-classification")

# Step 2: Classify image
image_path = "/content/beach.jpg"
result = classifier(image_path)

# Step 3: Format result nicely
object_details = []
for item in result:
    label = item['label']
    score = item['score'] * 100
    object_details.append(f"{label} ({score:.2f}%)")

classified_objects_str = ", ".join(object_details)

print("Detected Objects:")
print(classified_objects_str, "\n")

# Step 4: Load API key securely from Colab Secrets
api_key = userdata.get("ImageClassification")

# Step 5: Initialize Groq client
client = Groq(api_key=api_key)

# -------------------------------
# 🔹 1. Improved Description
# -------------------------------
prompt1 = f"""
Based on the detected objects below, write a creative and engaging description of the image in 2 to 3 lines.

Objects:
{classified_objects_str}

Make the description vivid, natural, and easy to imagine.
"""

response1 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt1}]
)

print("📌 Description of Image:")
print(response1.choices[0].message.content, "\n")


# -------------------------------
# 🔹 2. Funny Description
# -------------------------------
prompt2 = f"""
Describe this image in a funny way based on these objects:

{classified_objects_str}
"""

response2 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt2}]
)

print("😂 Funny Description:")
print(response2.choices[0].message.content, "\n")


# -------------------------------
# 🔹 3. Story Description
# -------------------------------
prompt3 = f"""
Describe this image as if you are telling a short story.

Objects:
{classified_objects_str}
"""

response3 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt3}]
)

print("📖 Story Description:")
print(response3.choices[0].message.content, "\n")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Detected Objects:
# seashore, coast, seacoast, sea-coast (96.22%), sandbar, sand bar (1.39%), promontory, headland, head, foreland (0.41%), beacon, lighthouse, beacon light, pharos (0.32%), lakeside, lakeshore (0.19%)
#
# 📌 Description of Image:
# "A sweeping crescent of shore, where the vibrant blue of the sea meets the soft golden warmth of sand, forming a tranquil haven that beckons the heart and soothes the soul. The gentle rhythmic lapping of waves on the sandy bar creates a soothing melody, as the lighthouse stands vigilantly, a steadfast guardian of this serene seacoast retreat."
#
# 😂 Funny Description:
# It looks like we have a real treasure trove of ocean-related words here. Let me paint a hilarious picture for you.
#
# Imagine a beach, but not just any beach. It's got a bar - a sand bar, duh! But not just any sand bar, it's a promontory (say that three times fast), a foreland if you will, sticking out into the sea like a giant's arm waving goodbye to all the surfers and beach bunnies.
#
# On this majestic coastline, a proud beacon shines its lighthouse light high into the air, warning all seafarers to steer clear (or not, if they're feeling adventurous). It's like a giant disco ball saying, "Yo, I'm over here, come and get it!"
#
# But wait, there's more! This isn't just a seashore; it's a lakeside (yes, you read that right) where the lake meets the ocean, creating a majestic sight that'll leave you speechless. The sea-coast is where the magic happens, where the waves crash against the shore, and the sound of gulls fills the air.
#
# And finally, on this scenic route, you'll find a headland (don't worry, it's not a real head, but a promontory, remember?), a pharos (that's Greek for lighthouse, in case you were wondering) watching over all the beachgoers, ensuring their safety (or not, if they're feeling lucky).
#
# That's what's happening in this picture, folks! A real oceanic extravaganza.
#
# 📖 Story Description:
# It was a serene morning at the seashore, the sun just starting to peek over the horizon. The air was filled with the sweet scent of salt and the sound of gentle waves crashing against the coast. The soft, sandy beach stretched out before us, with a few scattered beach towels and empty shells dotting the sand.
#
# As I walked along the shore, I noticed a small sandbar jutting out into the water, creating a picturesque cove. The waves caressed its edge, creating a soothing melody that seemed to calm the soul. To the left, a prominent headland rose up from the sea, its rugged rocks worn smooth by the relentless pounding of the ocean.
#
# A beacon stood tall at the edge of the headland, its lighthouse tower slicing through the morning mist. The beacon light shone brightly, a reassuring sentinel that guided sailors safely through the treacherous waters. As I looked out at the sea, I couldn't help but feel a sense of awe at the vast expanse of the ocean, its mysteries and power humbling me in equal measure.
#
# Further inland, the coast gave way to a tranquil lakeside, its peaceful waters reflecting the vibrant colors of the surrounding landscape. A small wooden dock stretched out into the lake, its weathered boards worn from years of use. The gentle lapping of the water against the shore created a soothing background noise, a perfect accompaniment to a day spent in nature's beauty.
